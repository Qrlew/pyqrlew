# %%
import pyqrlew as qrl
from pyqrlew.io import PostgreSQL

DB = PostgreSQL()
DATASET = DB.extract()
# Out:
# Error response from daemon: network with name qrlew-net already exists
# Error response from daemon: No such container: pyqrlew-db
# Error: failed to start containers: pyqrlew-db
# 881c7a0c18e66da1174c8aa86baa9123f626193e18e3a8537193439a76034a83
# /var/run/postgresql:5432 - no response
# Waiting postgresql to be ready...
# /var/run/postgresql:5432 - accepting connections
# SET
# SET
# SET
# SET
# SET
#  set_config
# ------------
#
# (1 row)
#
# SET
# SET
# SET
# SET
# CREATE SCHEMA
# ALTER SCHEMA
# COMMENT
# SET
# SET
# CREATE TABLE
# ALTER TABLE
# CREATE TABLE
# ALTER TABLE
# COPY 100
# COPY 199

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 6.6 MB/s eta 0:00:011
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1
# WARNING: You are using pip version 21.1.1; however, version 23.3 is available.
# You should consider upgrading via the '/Users/andicuko/Documents/Projects/pyqrlew/.venv/bin/python -m pip install --upgrade pip' command.

# %%
from graphviz import Source
from IPython.display import display

def display_dot(dot_graph):
    # graph = Source(dot_graph)

    # # # Set the size of the graph
    # # graph.graph_attr['size'] = '8,6'  # Adjust the width and height as needed

    # # # Render the graph to a PNG image
    # # graph.format = 'png'
    # graph.render(filename='graph', format='png', cleanup=True)

    # # Display the graph image with a specific size
    # display(Image(filename='graph.png', width=1600))
    display(Source(dot_graph))

# %%
for p,rel in DATASET.relations():
    print(p)
    print(rel.render())
    display_dot(rel.dot())
# Out:
# ['extract', 'extract', 'beacon']
# SELECT * FROM extract.beacon AS extract_beacon
# ['extract', 'extract', 'census']
# SELECT * FROM extract.census AS extract_census

# %%
result = DATASET.sql('SELECT age, count(age) FROM extract.census GROUP BY age')
Source(result.dot())

# %%
queries = [
    (("sch", "tab1"), 'SELECT age, count(age) FROM extract.census GROUP BY age LIMIT 10')
]
ds = DATASET.sql_from_dict(queries)
print(ds)
# Out:
# Dataset: {}
# Schema: {"name": "sch", "type": {"name": "Struct", "struct": {"fields": [{"name": "sarus_data", "type": {"name": "Union", "union": {"fields": [{"name": "tab1", "type": {"name": "Struct", "struct": {"fields": [{"name": "age", "type": {"name": "Integer", "integer": {"min": "-9223372036854775808", "max": "9223372036854775807"}}}, {"name": "field_vefg", "type": {"name": "Integer", "integer": {"max": "199"}}}]}}}]}}}, {"name": "sarus_protected_entity", "type": {"name": "Optional", "optional": {"type": {"name": "Id", "id": {}}}}}, {"name": "sarus_is_public", "type": {"name": "Boolean", "boolean": {}}}, {"name": "sarus_weights", "type": {"name": "Float", "float": {"max": 1.7976931348623157e308}}}]}}}
# Size: {"statistics": {"name": "Union", "union": {"fields": [{"name": "tab1", "statistics": {"struct": {"size": "10"}}}]}}}

# %%
print(ds.schema())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/andicuko/Documents/Projects/pyqrlew/examples/test_multi_schema.ipynb Cell 7 line 1
# ----> <a href='vscode-notebook-cell:/Users/andicuko/Documents/Projects/pyqrlew/examples/test_multi_schema.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> print(ds.schema())
#
# AttributeError: 'builtins.Dataset' object has no attribute 'schema'
